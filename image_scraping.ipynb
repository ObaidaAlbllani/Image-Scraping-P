# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time

#  Any infinity scroll URL
var = "trees"
url = "https://in.pinterest.com/search/pins/?q=" + var 
ScrollNumber = 4  # The depth we wish to load
sleepTimer = 1    # Waiting 1 second for page to load
resolvedURLs = []


options = webdriver.ChromeOptions() 
options.add_experimental_option("excludeSwitches", ["enable-logging"])

driver = webdriver.Chrome(options=options)  
driver.get(url)

for _ in range(1,ScrollNumber):
    driver.execute_script("window.scrollTo(1,100000)")
    print("scrolling")
    time.sleep(sleepTimer)

soup = BeautifulSoup(driver.page_source,'html.parser')

driver.close()
# Out:
# scrolling
# scrolling
# scrolling

# %%
for link in soup.find_all('img'):
   src = link.get('src')
   resolvedURLs.append(requests.compat.urljoin(url, src))
   #print(link.get('alt'))


print(resolvedURLs)

for re_url in range(len(resolvedURLs)):
    resolvedURLs[re_url]=resolvedURLs[re_url].replace("236x", "originals")

print(resolvedURLs)




for image in resolvedURLs:
    webs = requests.get(image)
    open('C:/Users/ASUS/GP/test_img/' + image.split('/')[-1], 'wb').write(webs.content)
# Out:
# ['https://i.pinimg.com/236x/52/a7/f6/52a7f65001264b58c1147fe3c8379a4e--pine-tree-blue-moon.jpg', 'https://i.pinimg.com/236x/5c/65/d9/5c65d9459d8b0d26167e1f10eb97e8fb.jpg', 'https://i.pinimg.com/236x/db/54/f6/db54f6aec86fdd0624af13bbc4468848--heart-tree-heart-shapes.jpg', 'https://i.pinimg.com/236x/98/c6/8b/98c68bc3b3b1f8d190f6d35e0e0310e5.jpg', 'https://i.pinimg.com/236x/9c/54/d1/9c54d18427cf289d5f5ea7a9f85292ec.jpg', 'https://i.pinimg.com/236x/45/90/42/459042fcbfa6dbd64f0c833938c0bf32.jpg', 'https://i.pinimg.com/236x/48/a0/c3/48a0c3b75a98ec2ddf761da7653c4c79.jpg', 'https://i.pinimg.com/236x/84/03/62/840362f0498c3324b820a928324a1e64--beech-tree-th-century.jpg', 'https://i.pinimg.com/236x/15/53/f5/1553f507ae736176e250efdc12c43b28.jpg', 'https://i.pinimg.com/236x/5d/85/54/5d855409204e246713875bcbc9942096--christmas-jumper-day-hut.jpg', 'https://i.pinimg.com/236x/dd/2c/b7/dd2cb7d69b70686c719f8b218a5c7b92--charleston-south-carolina-charleston-sc.jpg', 'https://i.pinimg.com/236x/35/7e/fc/357efce5c95eb27e7fd3e026ac923674.jpg', 'https://i.pinimg.com/236x/0c/8a/4e/0c8a4e5be566e6f1ad4d211c1e8089a0--new-england-fall-foliage-new-england-autumn.jpg', 'https://i.pinimg.com/236x/3d/b4/40/3db4400202f85d9d16ea835ec38d146f.jpg', 'https://i.pinimg.com/236x/4e/17/00/4e170010a6e75ba4434d729fe6890cf4--tree-graphic-image-gif.jpg', 'https://i.pinimg.com/236x/65/25/d9/6525d95f0a613f0f5ab78b3e655d5654--blossom-garden-pink-garden.jpg', 'https://i.pinimg.com/236x/e0/20/2a/e0202a53c6a1e1ac14a5fe279d18626a--foggy-forest-dark-forest.jpg', 'https://i.pinimg.com/236x/9c/86/f5/9c86f590fa399da979ddfe5e5c41d953--tropical-fruits-exotic-fruit.jpg', 'https://i.pinim